# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries loaded successfully!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Libraries loaded successfully!
# Pandas version: 3.0.3
# NumPy version: 2.5.1

# %%
df = pd.read_csv('../data/creditcard.csv')
print("Dataset loaded!")
print(f"Total Rows: {df.shape[0]:,}")
print(f"Total Columns: {df.shape[1]}")
# Out:
# Dataset loaded!
# Total Rows: 28,492
# Total Columns: 31

# %%
df.head()
# Out:
#     Time     Amount        V1        V2        V3        V4        V5  \
# 0  84289  60.295345  0.440591 -0.476872 -0.410264  0.649360  1.232515
# 1  60403  59.457726  0.139320  0.177205 -0.927925  0.488691  2.174095
# 2  85708  50.266529 -0.612450 -0.131749 -0.968340 -1.073705 -0.084989
# 3   2106  20.374098  0.620369 -0.705394 -0.684333 -0.726553  0.975334
# 4  87794  74.404582 -0.422916  0.775580 -0.659981 -0.105554 -0.885714
#
#          V6        V7        V8  ...       V20       V21       V22       V23  \
# 0  0.538290  1.805047 -0.930032  ... -1.268682  0.852816 -0.059911 -0.439337
# 1 -0.867605  0.747421 -0.647551  ...  0.450151 -1.583905  0.480066 -0.475103
# 2 -1.064103  0.001083  0.195778  ...  0.617788  0.232770 -0.726042 -0.277061
# 3  0.888883 -0.328055 -1.710953  ...  0.607199  0.445579 -0.147260 -2.127339
# 4 -0.252135 -0.266810 -1.502035  ...  0.258794 -0.815517 -0.844128 -1.080143
#
#         V24       V25       V26       V27       V28  Class
# 0 -0.401625 -0.897349  0.325545  1.019431 -1.104326      0
# 1  1.505636 -1.331032 -0.849512  0.051722 -1.798448      0
# 2  0.432112  0.404965 -1.337844  1.771711  1.061879      0
# 3  0.456848 -0.581064  1.220951 -1.195344  3.182740      0
# 4  0.243156 -1.054886  0.416659  0.616579 -0.423447      0
#
# [5 rows x 31 columns]

# %%
print("Missing values:")
print(df.isnull().sum().sum())
# Out:
# Missing values:
# 0

# %%
fraud_count = df['Class'].value_counts()
print(f"Normal transactions:    {fraud_count[0]:,}  ({fraud_count[0]/len(df)*100:.2f}%)")
print(f"Fraudulent transactions: {fraud_count[1]:,}  ({fraud_count[1]/len(df)*100:.2f}%)")
# Out:
# Normal transactions:    28,000  (98.27%)
# Fraudulent transactions: 492  (1.73%)
